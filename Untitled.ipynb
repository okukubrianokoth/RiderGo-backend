# %%
#basic function in Python
def greet():
  print("hello")
greet()
# Out:
# hello

# %%
#function with parameters : key idea; parameters receive data and arguements sends data
def greet(name):
  print("hello", name)
greet("Brian")
# Out:
# hello Brian

# %%
#function with return value
def add(a, b):
  return a + b
result = (10,20)
print (result)
# Out:
# (10, 20)
